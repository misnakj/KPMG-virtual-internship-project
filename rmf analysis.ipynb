# %%
  import numpy as np
  import pandas as pd

# %%
df=pd.read_csv("/content/joining.csv",sep=',')
df
# Out:
#        customer_id first_name  last_name  gender  \
# 0              1.0    Laraine  Medendorp  Female
# 1              1.0    Laraine  Medendorp  Female
# 2              1.0    Laraine  Medendorp  Female
# 3              1.0    Laraine  Medendorp  Female
# 4              1.0    Laraine  Medendorp  Female
# ...            ...        ...        ...     ...
# 20505          NaN        NaN        NaN     NaN
# 20506          NaN        NaN        NaN     NaN
# 20507          NaN        NaN        NaN     NaN
# 20508          NaN        NaN        NaN     NaN
# 20509          NaN        NaN        NaN     NaN
#
#        past_3_years_bike_related_purchases job_industry_category  \
# 0                                     93.0                Health
# 1                                     93.0                Health
# 2                                     93.0                Health
# 3                                     93.0                Health
# ...

# %%
# Display the first few rows of the dataset to understand its structure
print(df.head())
# Out:
#    customer_id first_name  last_name  gender  \
# 0          1.0    Laraine  Medendorp  Female
# 1          1.0    Laraine  Medendorp  Female
# 2          1.0    Laraine  Medendorp  Female
# 3          1.0    Laraine  Medendorp  Female
# 4          1.0    Laraine  Medendorp  Female
#
#    past_3_years_bike_related_purchases job_industry_category wealth_segment  \
# 0                                 93.0                Health  Mass Customer
# 1                                 93.0                Health  Mass Customer
# 2                                 93.0                Health  Mass Customer
# 3                                 93.0                Health  Mass Customer
# 4                                 93.0                Health  Mass Customer
#
#   deceased_indicator owns_car  tenure  ... product_size standard_cost  \
# 0                  N      Yes    11.0  ...       medium        125.07
# 1                  N      Yes    11.0  ...       medium        826.51
# ...

# %%
df.shape
# Out:
# (20510, 30)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'job_industry_category',
#        'wealth_segment', 'deceased_indicator', 'owns_car', 'tenure', 'dob1',
#        'transaction_id', 'product_id', 'customer_id.1', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'standard_cost',
#        'product_first_sold_date', 'list_price1', 'customer_id.2', 'address',
#        'postcode', 'state', 'country', 'property_valuation'],
#       dtype='object')

# %%
 print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20510 entries, 0 to 20509
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          20504 non-null  float64
#  1   first_name                           20504 non-null  object
#  2   last_name                            19849 non-null  object
#  3   gender                               20504 non-null  object
#  4   past_3_years_bike_related_purchases  20504 non-null  float64
#  5   job_industry_category                17180 non-null  object
#  6   wealth_segment                       20504 non-null  object
#  7   deceased_indicator                   20504 non-null  object
#  8   owns_car                             20504 non-null  object
#  9   tenure                               20047 non-null  float64
#  10  dob1                                 20038 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# customer_id                               6
# first_name                                6
# last_name                               661
# gender                                    6
# past_3_years_bike_related_purchases       6
# job_industry_category                  3330
# wealth_segment                            6
# deceased_indicator                        6
# owns_car                                  6
# tenure                                  463
# dob1                                    472
# transaction_id                          510
# product_id                              510
# customer_id.1                           510
# transaction_date                        510
# online_order                            870
# order_status                            510
# brand                                   707
# product_line                            707
# product_class                           707
# product_size                            707
# ...

# %%
df.dropna()
# Out:
#        customer_id first_name  last_name  gender  \
# 0              1.0    Laraine  Medendorp  Female
# 1              1.0    Laraine  Medendorp  Female
# 2              1.0    Laraine  Medendorp  Female
# 3              1.0    Laraine  Medendorp  Female
# 4              1.0    Laraine  Medendorp  Female
# ...            ...        ...        ...     ...
# 19999       3500.0       Josy    Fleeman  Female
# 20000       3500.0       Josy    Fleeman  Female
# 20001       3500.0       Josy    Fleeman  Female
# 20002       3500.0       Josy    Fleeman  Female
# 20003       3500.0       Josy    Fleeman  Female
#
#        past_3_years_bike_related_purchases job_industry_category  \
# 0                                     93.0                Health
# 1                                     93.0                Health
# 2                                     93.0                Health
# 3                                     93.0                Health
# ...

# %%
#convert transaction_date into date time format
df['transaction_date'] = pd.to_datetime(df['transaction_date'])
# Out:
# <ipython-input-9-9907bc0a564b>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['transaction_date'] = pd.to_datetime(df['transaction_date'])

# %%
# Calculate Recency
max_date = df['transaction_date'].max()
max_date
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
RFM_table=df.groupby('customer_id').agg({'transaction_date': lambda x: (max_date - x.max()).days, # Recency
                                                'transaction_id': lambda x: len(x.unique()), # Frequency
                                                'list_price1': lambda x: x.sum()})    # Monetary

RFM_table['transaction_date'] = RFM_table['transaction_date'].fillna(0).astype(int)

RFM_table.rename(columns={'transaction_date': 'recency',
                         'transaction_id': 'frequency',
                         'list_price1': 'monetary_value'}, inplace=True)
RFM_table.head()
# Out:
#              recency  frequency  monetary_value
# customer_id
# 1.0                7         11       9084.4501
# 2.0               54          3       4149.0701
# 3.0              102          8       9888.2299
# 4.0              195          2       1047.7200
# 5.0               16          6       5903.2000

# %%
#calculate RFM score
quantiles = RFM_table.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#       recency  frequency  monetary_value
# 0.25     10.0        3.0       3247.4925
# 0.50     35.0        5.0       5519.5600
# 0.75     77.0        7.0       7834.2625

# %%
# Converting quantiles to a dictionary, easier to use.
quantiles = quantiles.to_dict()
##  RFM Segmentation ----
RFM_Segment = RFM_table.copy()
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def R_Class(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FM_Class(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4
RFM_Segment['R_Quartile'] = RFM_Segment['recency'].apply(R_Class, args=('recency',quantiles,))
RFM_Segment['F_Quartile'] = RFM_Segment['frequency'].apply(FM_Class, args=('frequency',quantiles,))
RFM_Segment['M_Quartile'] = RFM_Segment['monetary_value'].apply(FM_Class, args=('monetary_value',quantiles,))
RFM_Segment['RFMClass'] = RFM_Segment.R_Quartile.map(str) \
                            + RFM_Segment.F_Quartile.map(str) \
                            + RFM_Segment.M_Quartile.map(str)

# %%
#best customers
RFM_Segment[RFM_Segment['RFMClass']=='444'].sort_values('monetary_value', ascending=False).head()
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# 2183.0             8         14      19071.3200           4           4
# 1140.0             6         13      16199.2398           4           4
# 729.0              1         10      15826.0002           4           4
# 1317.0            10          9      15370.8099           4           4
# 1329.0             4         11      14818.1200           4           4
#
#              M_Quartile RFMClass
# customer_id
# 2183.0                4      444
# 1140.0                4      444
# 729.0                 4      444
# 1317.0                4      444
# 1329.0                4      444

# %%
#customers who are at the verge od churning
#Customers who's recency value is low

RFM_Segment[RFM_Segment['R_Quartile'] <= 2 ].sort_values('monetary_value', ascending=False).head(5)
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# 1129.0            44         13      18349.2702           2           4
# 2788.0            44         11      17258.9399           2           4
# 1887.0            43         11      17133.9302           2           4
# 1302.0            55         13      17035.8299           2           4
# 2874.0            60         11      15091.9102           2           4
#
#              M_Quartile RFMClass
# customer_id
# 1129.0                4      244
# 2788.0                4      244
# 1887.0                4      244
# 1302.0                4      244
# 2874.0                4      244

# %%
#lost customers
#Customers who's recency, frequency as well as monetary values are low

RFM_Segment[RFM_Segment['RFMClass']=='111'].sort_values('recency',ascending=False).head(5)
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# 2328.0           356          1          441.49           1           1
# 2394.0           354          1          980.37           1           1
# 2423.0           353          1          202.62           1           1
# 1846.0           333          1          441.49           1           1
# 2525.0           330          1         1977.36           1           1
#
#              M_Quartile RFMClass
# customer_id
# 2328.0                1      111
# 2394.0                1      111
# 2423.0                1      111
# 1846.0                1      111
# 2525.0                1      111

# %%
#loyal customers
#Customers with high frequency value

RFM_Segment[RFM_Segment['F_Quartile'] >= 3 ].sort_values('monetary_value', ascending=False).head(5)
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# 2183.0             8         14      19071.3200           4           4
# 1129.0            44         13      18349.2702           2           4
# 1597.0            29         12      18052.6800           3           4
# 941.0             33         10      17898.4600           3           4
# 2788.0            44         11      17258.9399           2           4
#
#              M_Quartile RFMClass
# customer_id
# 2183.0                4      444
# 1129.0                4      244
# 1597.0                4      344
# 941.0                 4      344
# 2788.0                4      244
